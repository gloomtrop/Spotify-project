# %%
import spotipy
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials
import json
import requests
import matplotlib.pyplot as plt
import numpy as np

# %%
client_id = "cfae644792634e38955f936c52f65180"
client_secret = "27484f67a58644bdabd9c9d67421a251"

# %%
client_credentials_manager = SpotifyClientCredentials(client_id = client_id,
                                                     client_secret = client_secret)
sp = spotipy.Spotify(client_credentials_manager =client_credentials_manager)

birdy_uri = 'spotify:artist:2WX2uTcsvV5OnS0inACecP'

results = sp.artist_albums(birdy_uri, album_type='album')
albums = results['items']
while results['next']:
    results = spotify.next(results)
    albums.extend(results['items'])

for album in albums:
    print(album['name'])
# Out:
# Beautiful Lies
# Beautiful Lies
# Beautiful Lies (Deluxe)
# Beautiful Lies (Deluxe)
# Fire Within
# Fire Within
# Fire Within (Deluxe)
# Fire Within (Deluxe)
# Fire Within (Deluxe)
# Live in London
# Birdy
# Birdy
# Birdy
# Birdy
# Birdy (Deluxe Version)

# %%
playlists = sp.user_playlists(user ="jensroo")
# results["items"][0]
col_names = list()
mine = pd.Series([], dtype = "bool")

while playlists:
    for i, playlist in enumerate(playlists['items']):
        rows = dict()
        print(playlist["name"], i+playlists["offset"])
        user = input("yours?:")
        if user == "t":
            mine[i+playlists["offset"]] = True
        else:
            mine[i+playlists["offset"]] = False
        for key,value in playlist.items():
            rows[key] = [value]
#         display(pd.Series(rows))

        if i == 0 and playlists["offset"] == 0:

            playlists_df = pd.DataFrame(rows)
        else:
#             display(pd.DataFrame(rows))
#             print("hej")
            playlists_df = playlists_df.append(pd.DataFrame(rows), ignore_index = True)
            
    
#         print(
#             "%4d %s %s" %
#             (i +
#              playlists['offset'],
#              playlist['uri'],
#              playlist['name']))
    if playlists['next']:
        playlists = sp.next(playlists)
    else:
        playlists = None
playlists_df
# print(pd.DataFrame(results))
# for i, item in enumerate(results['items']):
#     print("%d %s %s" % (i, item['name'], item["id"]))
# Out:
# WANNABE – ITZY 0
# yours?:t
# TENTA 1
# yours?:f
# Pallen 2018 (VI-LING) 2
# yours?:f
# Min spellista nr 314 3
# yours?:t
# Cykla till skolan <33 4
# yours?:f
# Min spellista nr 313 5
# yours?:t
# filmmusik 6
# yours?:f
# Min spellista nr 313 7
# yours?:t
# -.- 8
# yours?:f
# mode19 9
# yours?:f
# 20lugnt 10
# yours?:f
# 20feel good 11
# yours?:f
# SISTA F***ING DAGEN!! 12
# yours?:f
# Sportcamp - Kickboxning 13
# yours?:f
# springlista 14
# yours?:f
# old goodies 15
# yours?:t
# Min spellista nr 309 16
# yours?:t
# This Is: Max Martin 17
# yours?:t
# You Raise Me Up – Josh Groban 18
# yours?:t
# Hero too – KYOKA JIRO Starring Chrissy Costanza 19
# yours?:t
# Lit fam  20
# yours?:f
# 20hopprep 21
# yours?:f
# 20ultimate 22
# yours?:f
# 20svenskt 23
# yours?:f
# 20Fit4t 24
# yours?:f
# 20Sydamerika  25
# yours?:f
# 20Vibz 26
# yours?:f
# Ultimate Party Classics 27
# yours?:t
# Island Music (Hawaiian & Reggae Blend) 28
# yours?:f
# The Hawaiian Party 29
# yours?:f
# Apink 30
# ...

# %%
mine.to_excel(r'mine.xlsx', index = False)

# %%
pp = playlists_df.copy()
print(len(mine))
pp["Mine"] = mine
pp

playlists_df["Mine"] = mine
# Out:
# 357

# %%
for j, playlist in playlists_df.iterrows():
    tracks = sp.playlist(playlist["uri"])["tracks"]
    while tracks:
        for i, track in enumerate(tracks["items"]):
            rows = dict()
            if track["track"] != None:
                for key,value in track["track"].items():
                    rows[key] = [value]
                if playlist["Mine"] == True:
                    rows["Mine"] = [True]
                else:
                    rows["Mine"] = [False]
            
            if i == 0 and tracks["offset"] == 0 and j ==0:

                tracks_df = pd.DataFrame(rows)
            else:
                tracks_df = tracks_df.append(pd.DataFrame(rows), ignore_index = True)

        if tracks['next']:
            tracks = sp.next(tracks)
        else:
            tracks = None
# tracks_df

# %%
tracks_df.head()
tracks_df.sort_values("Mine", ascending = False, inplace = True)
tracks_df.drop_duplicates("uri",keep = "first", ignore_index = True, inplace = True)

# %%
tracks_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9658 entries, 0 to 9657
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   album              9658 non-null   object
#  1   artists            9658 non-null   object
#  2   available_markets  9658 non-null   object
#  3   disc_number        9658 non-null   int64
#  4   duration_ms        9658 non-null   int64
#  5   episode            9637 non-null   object
#  6   explicit           9658 non-null   bool
#  7   external_ids       9658 non-null   object
#  8   external_urls      9658 non-null   object
#  9   href               9637 non-null   object
#  10  id                 9637 non-null   object
#  11  is_local           9658 non-null   bool
#  12  name               9658 non-null   object
#  13  popularity         9658 non-null   int64
#  14  preview_url        5344 non-null   object
#  15  track              9637 non-null   object
# ...

# %% [markdown]
# Getting the first 50 most popular tracks

# %%
endpoint_url = "https://api.spotify.com/v1/me/top/tracks?"
limit=50
time_range = "long_term"
offset = 0

query = f'{endpoint_url}limit={limit}&time_range={time_range}&offset={offset}'

response =requests.get(query, 
               headers={"Content-Type":"application/json", 
                        "Authorization":"Bearer BQAR4kA383kM_Z3iJ_fMzgZO49ZsUmTsm1VZMYMFW4K-eiTXvnGDrDChReNjV_Vumj82Rg_h0qGFByuxGXQ67xEgp5Q8NP2z22d9XYCZPW6w5-OVIKKofbi_fN64rdbIC2iB4MgLRKbBOdYwhbLlA-HpIDjZMPfQci-4WfjHJ8kuRTtOlWfo9519CFI"})
poptracks = response.json()

# %%
i = 0
for poptrack in poptracks["items"]:
            poprows = dict()
            if poptrack!= None:
                for key,value in poptrack.items():
#                     print(track["track"])
                    poprows[key] = [value]

            if i == 0:
                poptracks_df = pd.DataFrame(poprows)
                i = 1
            else:
                poptracks_df = poptracks_df.append(pd.DataFrame(poprows), ignore_index = True)

# %%
# poptracks_df = pd.DataFrame()
# while len(poptracks_df.index)<2000:
# 40 iterationer
endpoint_url = "https://api.spotify.com/v1/me/top/tracks?"
time_range = "long_term"
limit = 0

for i in range(1):
    offset = 52
    limit=50
    query = f'{endpoint_url}limit={limit}&time_range={time_range}&offset={offset}'
    
    response =requests.get(query, 
               headers={"Content-Type":"application/json", 
                        "Authorization":"Bearer BQCoMCe3d9mCWDkqoYivNSJMqo_QdJb1MinnuGzMLYfKpxTs12eyppaLvw78jtkxCVs-jThBAOnb3LYgdDn-rmOMU_YAqajqxOdqIFkeLvNV1QQGS5GV5aM4IRyw6B0na3GgQhxvtSAFVLuMDIqwc_DwCUWjnvDZPAINrW6PZuO9xAnnWu_5OaFMvo4"})
    poptracks = response.json()
    print(poptracks)
    for poptrack in poptracks["items"]:
            poprows = dict()
            print(sp.track(poptrack["uri"])["name"])
            if poptrack!= None:
                for key,value in poptrack.items():
#                     print(track["track"])
                    poprows[key] = [value]

            if i == 0:
                poptracks_df = pd.DataFrame(poprows)
            else:
                poptracks_df = poptracks_df.append(pd.DataFrame(poprows), ignore_index = True)

# %%
poptracks_df

# %%
for val,song in tracks_df["uri"].items():
#     print(tracks_df["Mine"][val],song)
    
    if "spotify:local:" not in song:
#         print(sp.audio_features(song))
        track = sp.audio_features(song)[0]
    
        trackrows = dict()
        if track != None:
            
            for key,value in track.items():
                trackrows[key] = [value]
            if tracks_df["Mine"][val] == True:
                trackrows["Mine"] = True
            else:
                trackrows["Mine"] = False
            
        if val == 0:
            tracksinfo_df = pd.DataFrame(trackrows)
        else:
            tracksinfo_df = tracksinfo_df.append(pd.DataFrame(trackrows), ignore_index = True)

# %%
display(tracksinfo_df)
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.809   0.911    6    -4.410     0       0.0617       0.00795
# 1            0.779   0.342    3    -6.316     0       0.0404       0.70100
# 2            0.591   0.719    8    -6.738     1       0.0461       0.02220
# 3            0.822   0.969    7   -11.471     0       0.0582       0.25900
# 4            0.727   0.939    8   -11.855     1       0.0369       0.13500
# ...            ...     ...  ...       ...   ...          ...           ...
# 9632         0.906   0.585    8    -7.720     0       0.3240       0.05770
# 9633         0.000   0.387    7    -8.395     0       0.0000       0.56400
# 9634         0.771   0.344    2    -9.274     1       0.9140       0.68300
# 9635         0.358   0.294    7   -15.400     1       0.0452       0.74100
# 9636         0.527   0.780    6    -4.305     1       0.0463       0.02590
#
# ...

# %%
tracksinfo_df.to_excel(r'tracks.xlsx', index = False)

# %%
songnames = pd.DataFrame()
for val,song in poptracks_df["uri"].items():
#     print(song)
    
    if "spotify:local:" not in song:
        poptrack = sp.audio_features(song)[0]
        print(val,sp.track(song)["name"])
        poptrackrows = dict()
        if poptrack != None:

            for key,value in poptrack.items():
                poptrackrows[key] = [value]
        if val == 0:
            poptracksinfo_df = pd.DataFrame(poptrackrows)
        else:
            poptracksinfo_df = poptracksinfo_df.append(pd.DataFrame(poptrackrows), ignore_index = True)
            
poptracksinfo_df["Favorite"] = True
# poptracksinfo_df

# %% [markdown]
# Till next time:
#
#  - Start exploring the tracks dataset and make some statistical analysis
#  - Implement a simple machine learning algorithm with test and training set
#  - Set up validation methods
#  - Explore what the algorithm can be used for
